# %%
print("Hello Python interpreter!")
# Out:
# Hello Python interpreter!

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
message = "Hello Python World!"
print(message)

message = "Hello Python Crash Course World!"
print(message)
# Out:
# Hello Python World!
# Hello Python Crash Course World!

# %% [markdown]
# Variable Names can only contain letters, numbers, and underscores. They can start with a letter or an underscore but not a numbers.
#
# Spaces are not allowed in variable names, but underscores can be used to separate words in variable names.
#
# Avoid using python keywords and function names as variables names; such as print.
#
# Variable Names should be short but descriptive.
#
# Be careful using lowercase letter l and upercase letter O as they may be mixed for for numbers 1 and 0.

# %%
message = "Hello Python Crash Course Reader!"
print(mesage)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-b2ddd18a976b> in <module>
#       1 message = "Hello Python Crash Course Reader!"
# ----> 2 print(mesage)
#
# NameError: name 'mesage' is not defined

# %%
message = "I think I understand this so far"
print(message)

message = "I hope that I can actually stick to this for a while"
print(message)
# Out:
# I think I understand this so far
# I hope that I can actually stick to this for a while

# %%
name = "ada lovelace"
print(name.title())
# Out:
# Ada Lovelace

# %% [markdown]
# using .title() we are able to transform the lowercase letters to uppercase as it's a title name.

# %%
name = "Ada Lovelace"
print(name.upper())
print(name.lower())
# Out:
# ADA LOVELACE
# ada lovelace

# %%
first_name = "ada"
last_name = "lovelace"
full_name = first_name + " " + last_name
print(full_name.title())
print("Hello, " + full_name.title() + "!")
# Out:
# Ada Lovelace
# Hello, Ada Lovelace!

# %%
print("Python")

print("\tPython")
# Out:
# Python
# 	Python

# %%
print("Languages:\n\tPython\n\tC\n\tJavascript")
# Out:
# Languages:
# 	Python
# 	C
# 	Javascript

# %%
favorite_language = 'python '
favorite_language
# Out:
# 'python '

# %%
favorite_language.rstrip()
# Out:
# 'python'

# %%
favorite_language = favorite_language.rstrip()

favorite_language
# Out:
# 'python'

# %%
favorite_language = ' python '
print(favorite_language.rstrip())
print(favorite_language.lstrip())
print(favorite_language.strip())
# Out:
#  python
# python
# python

# %%
favorite_language.rstrip()
# Out:
# ' python'

# %%
favorite_language.lstrip()
# Out:
# 'python '

# %%
favorite_language.strip()
# Out:
# 'python'

# %% [markdown]
# .rstrip() - used to remove whitespace on the right of the string.
#
# .lstrip() - used to remove whitespace on the left of the string.
#
# .strip() - used to remove whitespace on both sides of the string. possibly all the whitespace?

# %%
message = "One of python's strengths is its diverse community."
print(message)
# Out:
# One of python's strengths is its diverse community.

# %%
name = "jake"
print("Hello " + name.title() + ", would you like to learn some python today?")
# Out:
# Hello Jake, would you like to learn some python today?

# %%
name = "jake"
print(name.lower())
print(name.upper())
print(name.title())
# Out:
# jake
# JAKE
# Jake

# %%
famous_person = "albert einstein"
message = ' once said, "A person who never made a mistake never tried anything new."'
print(famous_person.title() + message)
# Out:
# Albert Einstein once said, "A person who never made a mistake never tried anything new."

# %%
name = " jake\t\nnichols "
name
name.lstrip()
name.rstrip()
name.strip()

name = name.strip().title()

name
# Out:
# 'Jake\t\nNichols'

# %%
print(name)
# Out:
# Jake
# Nichols

# %%
2 + 3
# Out:
# 2

# %%
3 - 2
# Out:
# 1

# %%
2 * 3
# Out:
# 6

# %%
3/2
# Out:
# 1.5

# %%
3**2
# Out:
# 9

# %%
3**3
# Out:
# 27

# %%
10**6
# Out:
# 1000000

# %%
2+3*4
# Out:
# 14

# %%
(2+3)*4
# Out:
# 20

# %%
0.1+0.1
# Out:
# 0.2

# %%
0.2+0.2
# Out:
# 0.4

# %%
2*0.1
# Out:
# 0.2

# %%
2*0.2
# Out:
# 0.4

# %%
0.2+0.1
# Out:
# 0.30000000000000004

# %%
3*0.1
# Out:
# 0.30000000000000004

# %%
age = 23
message = "Happy " + str(age) + "rd Birthday!"

print(message)
# Out:
# Happy 23rd Birthday!

# %%
print(4+4)
print(16-8)
print(16/2)
print(4*2)
# Out:
# 8
# 8
# 8.0
# 8

# %%
# I put my favorite number as 420
favorite_number = 420
#I need to use str() to convert the number variable to a string. 
message = "My favorite number is " + str(favorite_number) + "!"
# this is going to print what I've written above. 
print(message)
# Out:
# My favorite number is 420!

# %%
# This is a comment.
print("This isn't a comment!")
# Out:
# This isn't a comment!

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
print(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9ba126b17b03> in <module>
# ----> 1 print(name)
#
# NameError: name 'name' is not defined
